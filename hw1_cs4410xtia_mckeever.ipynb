# %% [markdown]
# <a href="https://colab.research.google.com/github/gabmck/cs4410/blob/main/hw1_cs4410xtia_mckeever.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### HW 1-Intro to Machine Learning-Gabby McKeever-Exercise 9.16

# %% [markdown]
# a. Github link for diamons.csv \
# b. load to pandas dataframe

# %%
import pandas as pd  # Import the pandas library and give it the alias 'pd'
import matplotlib.pyplot as plt  # Import the matplotlib library and give it the alias 'plt'

url = 'https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv'
df = pd.read_csv(url, index_col=0)  # Now you can use 'pd' to refer to pandas functions

# %% [markdown]
# c. display the first seven rows of the data frame

# %%
print(df.head(7))  # Display the first seven rows of the DataFrame
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 0.24   Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 0.24   Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %% [markdown]
# d. display the last seven rows of the data frame

# %%
print(df.tail(7))  # Display the last seven rows of the DataFrame
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.70   Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 0.72     Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 0.72       Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 0.72        Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 0.70   Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 0.86     Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 0.75       Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %% [markdown]
# e. Use the DataFrame method describe (which looks only at the numerical columns) to calculate the descriptive statistics for the numerical columns—carat, depth, table, price, x, y and z. \
#
# **I was getting an error for carat, and it seems like it's formatted differently in the dataset somehow so I removed just that one and the code worked. If you could give me any detail on why that happened so I can correct it moving forward, I would appreciate it! **bold text**

# %%
print(df[['depth', 'table', 'price', 'x', 'y', 'z']].describe())
# Out:
#               depth         table         price             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      61.749405     57.457184   3932.799722      5.731157      5.734526
# std        1.432621      2.234491   3989.439738      1.121761      1.142135
# min       43.000000     43.000000    326.000000      0.000000      0.000000
# 25%       61.000000     56.000000    950.000000      4.710000      4.720000
# 50%       61.800000     57.000000   2401.000000      5.700000      5.710000
# 75%       62.500000     59.000000   5324.250000      6.540000      6.540000
# max       79.000000     95.000000  18823.000000     10.740000     58.900000
#
#                   z
# count  53940.000000
# mean       3.538734
# std        0.705699
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %% [markdown]
# f. Use Series method describe to calculate the descriptive statistics for the categorical data (text) columns—cut, color and clarity.

# %%
print(df[['cut', 'color', 'clarity']].describe())
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# g. What are the unique category values (use the Series method unique)?

# %%
print(df['cut'].unique())
print(df['color'].unique())
print(df['clarity'].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %% [markdown]
# h. Pandas has many built-in graphing capabilities. Execute the %matplotlib magic to enable Matplotlib support in IPython. Then, to view histograms of each numerical data column, call your DataFrame’s hist method. The following figure shows the results for the DataFrame’s seven numerical columns:
#
# **had to omit carat again like in e.

# %%
# %matplotlib inline

# %%
df.hist(column=['depth', 'table', 'price', 'x', 'y', 'z'], figsize=(10, 10))
plt.show()
